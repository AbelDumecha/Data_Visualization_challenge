# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Weight and tumor volume has a strong positive relation, which shows that average tumor volume tends to increase with weight.
# - Based on the Summary Statistics table, Capomulin and Ramicane appear to be more effective in reducing tumor volume compared to other drug treatments, as they show consistently show lower tumor volumes (both in mean and median values).
# - It shows a negative correlation timepoint and total volume of the tumor for mouse l509 under Capomulin drug treatment. Even though there is flacutaion in the patern according to the line plot, overall, it shows that tumor volume decreases as days go by.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_study_results = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])
# Display the data table for preview
mouse_study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
number_of_mice = mouse_study_results["Mouse ID"].nunique()
number_of_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = mouse_study_results.loc[mouse_study_results.duplicated(subset=["Mouse ID", "Timepoint"], keep=False), "Mouse ID"].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data_df = mouse_study_results[mouse_study_results.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]
duplicate_mouse_id = duplicate_mouse_data['Mouse ID'].unique()
duplicate_mouse_data = mouse_study_results[mouse_study_results["Mouse ID"].isin(duplicate_mouse_id)]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_mouse_data = mouse_study_results[mouse_study_results["Mouse ID"].isin(duplicate_mouse_id)==False]
#cleaned_mouse_data = mouse_study_results.drop_duplicates()
cleaned_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
revised_number_mice = cleaned_mouse_data["Mouse ID"].nunique() 
revised_number_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 

# mean, median, variance, standard deviation, and SEM of the tumor volume. 

mean = cleaned_mouse_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].mean()
median = cleaned_mouse_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].median()
variance = cleaned_mouse_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].var()
standard_deviation = cleaned_mouse_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].std()
SEM = cleaned_mouse_data.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
statistics_summary_df = {
    "Mean Tumor Volume":mean, "Median Tumor Volume":median,"Tumor Volume Variance":variance,"Tumor Volume Std. Dev.":standard_deviation,
    "Tumor Volume Std. Err.":SEM
}

statistics_summary = pd.DataFrame(statistics_summary_df)

statistics_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
statistics_summary_opt = cleaned_mouse_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
statistics_summary_opt
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
#filter the DataFrame to display only the data  needed for the chart

drug_regimen_counts = cleaned_mouse_data['Drug Regimen'].value_counts()
drug_regimen_counts.plot(kind='bar', color='blue', alpha=0.75, align='center', ylabel = '# of observed Mouse Timepoints')
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

#create a bar plot
plt.bar(x=drug_regimen_counts.index, height=drug_regimen_counts.values, color='blue', alpha=0.75)
        
#set plot lables and Title
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice')
plt.title('# of Observed Mouse Timepoints')
plt.xticks(rotation='vertical')

#Adjusting and plot layout 
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

mouse_sex_counts = cleaned_mouse_data['Sex'].value_counts()

#create a pie plot
plot = mouse_sex_counts.plot.pie(labels=mouse_sex_counts.index, autopct='%1.1f%%', colors=['blue', 'orange']).set_ylabel('Sex')

#plot layout
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#create a pie plot
plt.pie(mouse_sex_counts, labels=mouse_sex_counts.index, autopct='%1.1f%%', colors=['blue', 'orange'])
plt.ylabel('Sex')
#plot layout
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
selected_treatment = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

#filter from the DataFrame

filtered_selected_treatment = cleaned_mouse_data[cleaned_mouse_data['Drug Regimen'].isin(selected_treatment)]
tumor_min_volume = filtered_selected_treatment.groupby(['Mouse ID', 'Drug Regimen'])['Tumor Volume (mm3)'].min().reset_index()

# Start by getting the last (greatest) timepoint for each mouse

timepoint_max = cleaned_mouse_data.groupby(['Mouse ID'])['Timepoint'].max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged_mouse_study_data = pd.merge(tumor_min_volume, timepoint_max, how="left", on=['Mouse ID'])
merged_mouse_study_data
# Out:
#    Mouse ID Drug Regimen  Tumor Volume (mm3)  Timepoint
# 0      a203    Infubinol           45.000000         45
# 1      a251    Infubinol           45.000000         45
# 2      a275     Ceftamin           45.000000         45
# 3      a411     Ramicane           38.087373         45
# 4      a444     Ramicane           41.714619         45
# ..      ...          ...                 ...        ...
# 95     y769     Ceftamin           45.000000         45
# 96     y793    Capomulin           31.475411         45
# 97     y865     Ceftamin           45.000000         45
# 98     z578     Ramicane           30.638696         45
# 99     z581    Infubinol           45.000000         45
#
# [100 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Locate the rows which contain mice on each drug and get the tumor volumes

    # add subset 

    # Determine outliers using upper and lower bounds

# loop through each treatments
for treatment in treatments_list:
    
    #filter the data for the corresponding current treatment
    treatment_data = merged_mouse_study_data[merged_mouse_study_data['Drug Regimen'] == treatment]

    #get the tumor volume data for the current treatment
    tumor_volumes = treatment_data['Tumor Volume (mm3)']
    
    #append the tumor volume data to the list
    tumor_vol_data.append(tumor_volumes)
    
    # Calculate the IQR (Interquartile Range) for the current treatment regimen
    quartiles = tumor_volumes.quantile([0.25, 0.5, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q

    # Determine the upper and lower bounds to identify potential outliers
    lower_bound = lower_q - (1.5 * iqr)
    upper_bound = upper_q + (1.5 * iqr)

    # Locate potential outliers for the current treatment regimen
    potential_outliers = treatment_data[(treatment_data['Tumor Volume (mm3)'] < lower_bound) | 
                                        (treatment_data['Tumor Volume (mm3)'] > upper_bound)]
    
    # Print or store the potential outliers for further analysis
    print(f"{treatment}'s potential outliers: {potential_outliers['Tumor Volume (mm3)']}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# Filter out duplicate mouse IDs
treatments_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
filtered_data = final_tumor_volume[final_tumor_volume['Drug Regimen'].isin(treatments_list)]

# Create a box plot 
plt.figure(figsize=(6, 4))
plt.boxplot([filtered_data[filtered_data['Drug Regimen'] == regimen]['Tumor Volume (mm3)'] for regimen in treatments_list],
            labels=treatments_list, flierprops=dict(marker='o', markerfacecolor='red', markersize=10))
plt.ylabel('Final Tumor Volume (mm3)')
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

#Filter data for mouse l509
mouse_data = cleaned_mouse_data[['Mouse ID', 'Drug Regimen', 'Timepoint', 'Tumor Volume (mm3)']]
mouse_l509_data = mouse_data[mouse_data['Mouse ID'] == 'l509']

#Collect timepoint and final tumor volume for mouse ID l509
timepoint =  mouse_l509_data['Timepoint'].values
final_tumor_volume =  mouse_l509_data['Tumor Volume (mm3)'].values

#Plot the specific treatment for mouse ID l509
plt.plot(timepoint, final_tumor_volume, color='Blue')
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin treatment of mouse l509')
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

#Filter the data for capomulin regimen
capomulin_data = cleaned_mouse_data[cleaned_mouse_data['Drug Regimen'] == 'Capomulin']

#Calculate the average tumor volume 
avg_tumor_vol = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

#Collect avg mouse weight
mouse_weight = capomulin_data.groupby('Mouse ID')['Weight (g)'].mean()

#Create a scatter plot
plt.scatter(mouse_weight, avg_tumor_vol, marker='o', facecolor='blue')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
mouse_weight = capomulin_data.groupby('Mouse ID')['Weight (g)'].mean()
mouse_weight
# Out:
# Mouse ID
# b128    22.0
# b742    21.0
# f966    17.0
# g288    19.0
# g316    22.0
# i557    24.0
# i738    20.0
# j119    23.0
# j246    21.0
# l509    21.0
# l897    19.0
# m601    17.0
# m957    19.0
# r157    25.0
# r554    17.0
# r944    25.0
# s185    17.0
# s710    23.0
# t565    17.0
# u364    17.0
# v923    21.0
# w150    23.0
# w914    21.0
# x401    15.0
# y793    17.0
# Name: Weight (g), dtype: float64

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

vol = avg_tumor_vol['Tumor Volume (mm3)'].values
weight = mouse_weight.values
correlation = st.pearsonr(weight, vol)

x_values  = weight
y_values = vol
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values + slope + intercept

print(f"The correlation between mouse weight and the average tumor is {round(correlation[0],2)}")

plt.scatter(weight, vol)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.plot(weight, intercept + slope * weight, color='red')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor is 0.84
